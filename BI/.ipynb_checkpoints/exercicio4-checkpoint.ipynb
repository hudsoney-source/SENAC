# %%
import numpy as np
arr = np.array([[1, 2, 3, 4, 5], [4, 5, 6, 7, 8], [7, 8, 9, 10, 11], [11, 12, 13, 14, 15]])
arr
# Out:
# array([[ 1,  2,  3,  4,  5],
#        [ 4,  5,  6,  7,  8],
#        [ 7,  8,  9, 10, 11],
#        [11, 12, 13, 14, 15]])

# %%
arr[2]
# Out:
# array([ 7,  8,  9, 10, 11])
