# %%
import pandas as pd
lista_frutas = ['Maçã', 'Banana', 'Morango', 'Uva', 'Abacaxi']
series_frutas = pd.Series(lista_frutas)
series_frutas
# Out:
# 0       Maçã
# 1     Banana
# 2    Morango
# 3        Uva
# 4    Abacaxi
# dtype: str
