# %%
import pandas as pd
import numpy as np
dados = np.array([10, 20, 30, 40])
series_customizada = pd.Series(dados, index=['A', 'B', 'C', 'D'])
series_customizada
# Out:
# A    10
# B    20
# C    30
# D    40
# dtype: int64
