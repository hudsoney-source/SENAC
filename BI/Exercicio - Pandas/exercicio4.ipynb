# %%
import pandas as pd
dados = {'jan': 100, 'fev': 200}
series_meses = pd.Series(dados, index=['jan', 'fev', 'mar'])
series_meses
# Out:
# jan    100.0
# fev    200.0
# mar      NaN
# dtype: float64
