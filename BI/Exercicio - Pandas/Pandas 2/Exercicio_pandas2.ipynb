# %%
# Exercicio1 

import pandas as pd
dados_alunos = {
    'Nome': ['Ana', 'Bruno', 'Carla', 'Diego', 'Eduarda'],
    'Idade': [15, 14, 16, 15, 17]
}
df = pd.DataFrame(dados_alunos)
df
# Out:
#       Nome  Idade
# 0      Ana     15
# 1    Bruno     14
# 2    Carla     16
# 3    Diego     15
# 4  Eduarda     17

# %%
# Exercicio2

dados_rh = [
    {'Nome': 'Ana', 'Cargo': 'Analista'},
    {'Nome': 'Bruno', 'Cargo': 'Gerente', 'Bonus': 500}
]
df = pd.DataFrame(dados_rh)
df
# Out:
#     Nome     Cargo  Bonus
# 0    Ana  Analista    NaN
# 1  Bruno   Gerente  500.0

# %%
# Exercicio3

nomes = pd.Series(['Notebook', 'Mouse', 'Teclado'], index=['p1', 'p2', 'p3'])
precos = pd.Series([4500.00, 120.00, 250.00], index=['p1', 'p2', 'p3'])

df_produtos = pd.DataFrame({
    'Produto': nomes,
    'Preço': precos
})
df_produtos
# Out:
#      Produto   Preço
# p1  Notebook  4500.0
# p2     Mouse   120.0
# p3   Teclado   250.0

# %%
# Exercicio4

dados = {
    'Sede A': [1000, 2500, 1800],
    'Sede B': [1500, 2000, 2200]
}
df = pd.DataFrame(dados)
df['Total Vendas'] = df['Sede A'] + df['Sede B']
df['Imposto'] = df['Sede A'] * 0.10
df
# Out:
#    Sede A  Sede B  Total Vendas  Imposto
# 0    1000    1500          2500    100.0
# 1    2500    2000          4500    250.0
# 2    1800    2200          4000    180.0

# %%
# Exercicio5

dados = {
    'Nome': ['Alice', 'Beto', 'Caio'],
    'CPF': ['111.111', '222.222', '333.333'],
    'Telefone': ['9999-0001', '9999-0002', '9999-0003'],
    'Cidade': ['SP', 'RJ', 'MG']
}
df = pd.DataFrame(dados)
df
# Out:
#     Nome      CPF   Telefone Cidade
# 0  Alice  111.111  9999-0001     SP
# 1   Beto  222.222  9999-0002     RJ
# 2   Caio  333.333  9999-0003     MG

# %%
del df['CPF']
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CPF'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 del df['CPF']
# ...

# %%
coluna_removida = df.pop('Telefone')
df
# Out:
#     Nome Cidade
# 0  Alice     SP
# 1   Beto     RJ
# 2   Caio     MG

# %%
# Exercicio6

dados = {
    'Capital': ['Brasília', 'Buenos Aires', 'Santiago'],
    'População': [214.3, 45.8, 19.2]
}
df_paises = pd.DataFrame(dados, index=['Brasil', 'Argentina', 'Chile'])
dados_brasil = df_paises.loc['Brasil']
dados_brasil
# Out:
# Capital      Brasília
# População       214.3
# Name: Brasil, dtype: object

# %%
# Exercicio7

dados_carros = {
    'Modelo': ['Fusca', 'Gol', 'Civic', 'Corolla', 'Palio', 'Uno'],
    'Ano': [1975, 2010, 2022, 2023, 2015, 2012]
}
df_carros = pd.DataFrame(dados_carros)
selecao = df_carros.iloc[3:5]
selecao
# Out:
#     Modelo   Ano
# 3  Corolla  2023
# 4    Palio  2015

# %%
# Exercicio8

import numpy as np
df_historico = pd.DataFrame({'Dados': range(1, 21)})
df_extraido = df_historico[4:12]
df_extraido
# Out:
#     Dados
# 4       5
# 5       6
# 6       7
# 7       8
# 8       9
# 9      10
# 10     11
# 11     12

# %%
# Exercicio9

df_loja1 = pd.DataFrame({'Produto': ['Teclado', 'Mouse'], 'Estoque': [10, 15]})
df_loja2 = pd.DataFrame({'Produto': ['Monitor', 'Headset'], 'Estoque': [5, 8]})
df_total = pd.concat([df_loja1, df_loja2], ignore_index=True)
df_total
# Out:
#    Produto  Estoque
# 0  Teclado       10
# 1    Mouse       15
# 2  Monitor        5
# 3  Headset        8

# %%
#Exercicio10

dados = {
    'Funcionário': ['Ana', 'Bruno', 'Carla', 'Diego', 'Elena'],
    'Salário': [5200.0, 4800.5, 7100.0, 3900.0, 6200.0]
}
df = pd.DataFrame(dados)
df.T
df.dtypes
df.tail(2)
# Out:
#   Funcionário  Salário
# 3       Diego   3900.0
# 4       Elena   6200.0
