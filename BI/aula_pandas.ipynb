# %%
import pandas as pd
data = [{'a':1, 'b':2}, {'a':5, 'b':10, 'c':20}]
df = pd.DataFrame(data)
df
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %%
dados = {'one': pd.Series([1., 2., 3.], index=['a', 'b', 'c']),
        'two': pd.Series([1., 2., 3., 4.], index=['a', 'b', 'c', 'd'])}
df = pd.DataFrame(dados)
df
# Out:
#    one  two
# a  1.0  1.0
# b  2.0  2.0
# c  3.0  3.0
# d  NaN  4.0

# %%
df['three'] = pd.Series([10., 20., 30.], index=['a', 'b', 'c'])
df
# Out:
#    one  two  three
# a  1.0  1.0   10.0
# b  2.0  2.0   20.0
# c  3.0  3.0   30.0
# d  NaN  4.0    NaN

# %%
df['four'] = df['three']
df
# Out:
#    one  two  three  four
# a  1.0  1.0   10.0  10.0
# b  2.0  2.0   20.0  20.0
# c  3.0  3.0   30.0  30.0
# d  NaN  4.0    NaN   NaN

# %%
del df['two']
df # exlusão de coluna utilizando a função DEL
# Out:
#    one  three  four
# a  1.0   10.0  10.0
# b  2.0   20.0  20.0
# c  3.0   30.0  30.0
# d  NaN    NaN   NaN

# %%
df.pop('three')
df # exclusão de coluna utilizando a função POP
# Out:
#    one  two  four
# a  1.0  1.0  10.0
# b  2.0  2.0  20.0
# c  3.0  3.0  30.0
# d  NaN  4.0   NaN
