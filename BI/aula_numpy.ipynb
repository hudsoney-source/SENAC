# %%
import numpy as np

# %%
vet = np.array([1, 2, 3, 6, 8, 9, 10, 11, 13, 14, 15, 101, 15, 13, 12, 3, 1])
vet
# Out:
# array([  1,   2,   3,   6,   8,   9,  10,  11,  13,  14,  15, 101,  15,
#         13,  12,   3,   1])

# %%
type(vet)
# Out:
# numpy.ndarray

# %%
vet2 = np.array([1, 2, 3, 4, 5])
vet2.cumsum()
# Out:
# array([ 1,  3,  6, 10, 15])

# %%
print(vet[4])
# Out:
# 8

# %%
vet[0] = -1
vet
# Out:
# array([ -1,   2,   3,   6,   8,   9,  10,  11,  13,  14,  15, 101,  15,
#         13,  12,   3,   1])

# %%
vet = np.append(vet, 202)
vet
# Out:
# array([ -1,   2,   3,   6,   8,   9,  10,  11,  13,  14,  15, 101,  15,
#         13,  12,   3,   1, 202])

# %%
vet = vet[:-1]
vet
# Out:
# array([ -1,   2,   3,   6,   8,   9,  10,  11,  13,  14,  15, 101,  15,
#         13,  12,   3,   1])

# %%
vet = np.delete(vet, -2)
vet
# Out:
# array([ -1,   2,   3,   6,   8,   9,  10,  11,  13,  14,  15, 101,  15,
#         13,  12,   1])

# %%
vet.shape
# Out:
# (16,)

# %%
vetor = np.array([[0, -5],[11, 300]])
vetor
# Out:
# array([[  0,  -5],
#        [ 11, 300]])

# %%
vetor.shape
# Out:
# (2, 2)

# %%
vetor3x2 = np.array([[1, 2], [3, 4], [5, 6]])
vetor3x2
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
vetor3x2.shape
# Out:
# (3, 2)

# %%
vetor2x3 = np.array([[1, 2, 3],[4, 5, 6]])
vetor2x3
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
vetor2x3.shape
# Out:
# (2, 3)

# %%
y = np.arange(2, 200, 5)
y
# Out:
# array([  2,   7,  12,  17,  22,  27,  32,  37,  42,  47,  52,  57,  62,
#         67,  72,  77,  82,  87,  92,  97, 102, 107, 112, 117, 122, 127,
#        132, 137, 142, 147, 152, 157, 162, 167, 172, 177, 182, 187, 192,
#        197])
