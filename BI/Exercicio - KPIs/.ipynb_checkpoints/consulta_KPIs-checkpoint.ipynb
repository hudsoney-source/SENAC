# %%
import pandas as pd

# %%
df = pd.read_csv("consulta.csv", sep=';', encoding='latin-1')
df
# Out:
#              Localidade                       Variável       2014       2015  \
# 0  Aparecida de Goiânia  Extensão de Redes de Água (m)  1.410.564  1.412.681
# 1  Aparecida de Goiânia      Ligações de Água (número)    106.804    112.958
# 2               Goiânia  Extensão de Redes de Água (m)  5.986.059  6.025.019
# 3               Goiânia      Ligações de Água (número)    487.489    508.551
#
#         2016       2017       2018       2019       2020       2021  \
# 0  2.280.256  2.284.362  2.986.612  2.996.942  3.078.070  3.089.591
# 1    120.023    125.787    129.532    134.878    141.053    146.651
# 2  6.638.653  6.712.636  7.597.018  7.650.590  7.685.920  7.703.343
# 3    525.667    538.941    551.704    565.143    575.423    590.953
#
#         2022       2023     2024
# 0  3.126.391  3.235.640  3327907
# 1    152.139    166.797   162845
# 2  7.798.021  7.949.878  8016799
# 3    600.776    647.025   622953

# %%
print(df.info())            # estrutura dos dados (EDA)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Localidade  4 non-null      str
#  1   Variável    4 non-null      str
#  2   2014        4 non-null      str
#  3   2015        4 non-null      str
#  4   2016        4 non-null      str
#  5   2017        4 non-null      str
#  6   2018        4 non-null      str
#  7   2019        4 non-null      str
#  8   2020        4 non-null      str
#  9   2021        4 non-null      str
#  10  2022        4 non-null      str
#  11  2023        4 non-null      str
#  12  2024        4 non-null      int64
# dtypes: int64(1), str(12)
# memory usage: 548.0 bytes
# None

# %%
print(df.isnull().sum())    # dados faltantes
# Out:
# Localidade    0
# Variável      0
# 2014          0
# 2015          0
# 2016          0
# 2017          0
# 2018          0
# 2019          0
# 2020          0
# 2021          0
# 2022          0
# 2023          0
# 2024          0
# dtype: int64

# %%
print(df.describe())        # KPIs estatísticos
# Out:
#                2024
# count  4.000000e+00
# mean   3.032626e+06
# std    3.604226e+06
# min    1.628450e+05
# 25%    5.079260e+05
# 50%    1.975430e+06
# 75%    4.500130e+06
# max    8.016799e+06
