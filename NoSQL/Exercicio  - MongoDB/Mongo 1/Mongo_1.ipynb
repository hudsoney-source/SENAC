# %%
from pymongo import MongoClient
import pandas as pd

client = MongoClient('mongodb://localhost:27017/')
filter = {}

result = client['local']['startup_log'].find(
    filter=filter
)

df = pd.DataFrame(list(result))

display(df)
# Out:
#                           _id      hostname           startTime  \
# 0  d1376e65646c-1773793748226  d1376e65646c 2026-03-18 00:29:08
# 1  d1376e65646c-1774388948929  d1376e65646c 2026-03-24 21:49:08
#
#             startTimeLocal                   cmdLine  pid  \
# 0  Wed Mar 18 00:29:08.226  {'net': {'bindIp': '*'}}    1
# 1  Tue Mar 24 21:49:08.929  {'net': {'bindIp': '*'}}    1
#
#                                            buildinfo
# 0  {'version': '8.2.6', 'versionArray': [8, 2, 6,...
# 1  {'version': '8.2.6', 'versionArray': [8, 2, 6,...
