# %%
from pathlib import Path

import pandas as pd

csv_path = Path('Transito.csv')
if not csv_path.exists():
    csv_path = Path('Big Data/Data Science/Atividade 1/Transito.csv')

dataset = pd.read_csv(csv_path, sep=';', encoding='latin1')
dataset
# Out:
#               Localidade                                Variável  2008  2009  \
# 0        Abadia de Goiás  Acidentes de Trânsito - Total (número)   103   105
# 1              Abadiânia  Acidentes de Trânsito - Total (número)   188   203
# 2                Acreúna  Acidentes de Trânsito - Total (número)   150   141
# 3              Adelândia  Acidentes de Trânsito - Total (número)     3     3
# 4     Água Fria de Goiás  Acidentes de Trânsito - Total (número)    37    19
# 5             Água Limpa  Acidentes de Trânsito - Total (número)     6     9
# 6  Águas Lindas de Goiás  Acidentes de Trânsito - Total (número)   326   406
# 7               Alexânia  Acidentes de Trânsito - Total (número)   243   292
# 8               Aloândia  Acidentes de Trânsito - Total (número)     9     4
# 9         Alto Horizonte  Acidentes de Trânsito - Total (número)    14    42
#
#    2010  2011  2012
# 0    88   111   129
# 1   220   202   241
# 2   163   172   198
# 3     3     4     8
# ...

# %%
dataset['2008'].mean()
# Out:
# np.float64(107.9)

# %%
dataset['Localidade'].max()
# Out:
# 'Águas Lindas de Goiás'

# %%
dataset['Localidade'].describe()
# Out:
# count                  10
# unique                 10
# top       Abadia de Goiás
# freq                    1
# Name: Localidade, dtype: object

# %%
dataset.loc[(dataset['2008'] > 25) & dataset['Localidade'].notna(), '2012'].count()
# Out:
# np.int64(6)

# %%
dataset.loc[(dataset['2008'] > 17) & dataset['Localidade'].notna(), '2012'].value_counts()
# Out:
# 2012
# 129    1
# 241    1
# 198    1
# 82     1
# 867    1
# 357    1
# Name: count, dtype: int64

# %%
dataset['2010'].value_counts().plot(kind='pie', title='2010', legend=True, table=True, autopct='%1.1f%%')
# Out:
# <Axes: title={'center': '2010'}>

# %%
dataset[(dataset['2008'] >= 1)]['2012'].hist(bins=30, color='red')
# Out:
# <Axes: >
